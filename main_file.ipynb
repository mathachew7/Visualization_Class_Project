# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
# Load the dataset into separate DataFrames for each sheet
sheets = ['Exports', 'Imports', 'Production', 'Inventories', 'Consumption', 'IndicatorPrice']
dfs = {sheet: pd.read_excel('ico_coffee_dataset.xlsx', sheet_name=sheet) for sheet in sheets}

# %%
exports_df = dfs['Exports']
import_df = dfs['Imports']
production_df = dfs['Production']
inventory_df = dfs['Inventories']
consumption_df = dfs['Consumption']
indicatorPrice_df = dfs['IndicatorPrice']

# %%
exports_df.head()
# Out:
#                             Country        1990          1991          1992  \
# 0                            Angola     84.3500     70.501000     80.250000
# 1  Bolivia (Plurinational State of)    156.4420     73.523000     96.204000
# 2                            Brazil  16935.7876  21182.761402  18790.719202
# 3                           Burundi    584.7730    687.851000    645.858000
# 4                          Cameroon   2611.2590   1752.179000   1645.851000
#
#            1993        1994          1995          1996          1997  \
# 0     38.878000      8.3020     40.559000     51.831000     50.494000
# 1     47.319000     84.3210     93.958000    123.445000    110.955000
# 2  17837.747999  17273.1476  14468.432201  15250.609002  16801.260005
# 3    417.609000    507.8030    528.202000    224.076000    528.764000
# 4    704.530000    545.8890    407.269000    563.549000   1368.030000
#
#            1998  ...          2010          2011          2012          2013  \
# ...

# %% [markdown]
# ## Handling Export Sheet with all the missing Values and Treating it right.

# %%
export_missing = exports_df.isnull().sum()

# %%
exports_df = exports_df.dropna()

# %%
# Explore the data by printing the first few rows and summary statistics
print(exports_df.head())
print(exports_df.describe())
# Out:
#                             Country        1990          1991          1992  \
# 0                            Angola     84.3500     70.501000     80.250000
# 1  Bolivia (Plurinational State of)    156.4420     73.523000     96.204000
# 2                            Brazil  16935.7876  21182.761402  18790.719202
# 3                           Burundi    584.7730    687.851000    645.858000
# 4                          Cameroon   2611.2590   1752.179000   1645.851000
#
#            1993        1994          1995          1996          1997  \
# 0     38.878000      8.3020     40.559000     51.831000     50.494000
# 1     47.319000     84.3210     93.958000    123.445000    110.955000
# 2  17837.747999  17273.1476  14468.432201  15250.609002  16801.260005
# 3    417.609000    507.8030    528.202000    224.076000    528.764000
# 4    704.530000    545.8890    407.269000    563.549000   1368.030000
#
#            1998  ...          2010          2011          2012          2013  \
# ...

# %% [markdown]
# ## Handling Import Sheet with all the missing Values and Treating it right.

# %%
# Check for missing values in the Import sheet
import_missing = import_df.isnull().sum()

# %%
import_missing
# Out:
# Country    0
# 1990       6
# 1991       6
# 1992       2
# 1993       2
# 1994       2
# 1995       2
# 1996       2
# 1997       2
# 1998       2
# 1999       1
# 2000       1
# 2001       1
# 2002       1
# 2003       1
# 2004       1
# 2005       1
# 2006       1
# 2007       1
# 2008       1
# 2009       1
# 2010       1
# 2011       1
# 2012       1
# 2013       1
# 2014       1
# 2015       1
# 2016       1
# 2017       1
# 2018       1
# 2019       1
# dtype: int64

# %%
#Handle missing values, for example, by dropping rows with missing values
import_df = import_df.dropna()

# %%
# Explore the data by printing the first few rows and summary statistics
print(import_df.head())
print(import_df.describe())
# Out:
#        Country         1990         1991         1992         1993  \
# 0      Austria  1879.717004  2058.271005  2206.416005  1836.489002
# 3     Bulgaria   268.182998   200.220001   182.231012   397.443006
# 5       Cyprus    49.853999    53.926000    40.875999    77.412000
# 6      Czechia   659.433000   525.274000   474.731003   514.277005
# 7      Denmark   959.105004   982.757004  1061.623004   993.947000
#
#           1994         1995         1996         1997         1998  ...  \
# 0  1417.214004  1231.436001  1210.466006  1294.203405  1293.354106  ...
# 3   462.668007   515.418008   272.159995   294.154003   342.122004  ...
# 5    51.836001    43.769000    51.501999    41.340999    49.778999  ...
# 6   553.797003   553.196999   525.298002   560.225003   764.839002  ...
# 7  1033.184003   877.159002  1005.999200   949.070500  1013.723201  ...
#
#           2010         2011         2012         2013         2014  \
# ...

# %% [markdown]
# ## Handling production Sheet with all the missing Values and Treating it right.

# %%
# Check for missing values in the Production sheet
production_missing = production_df.isnull().sum()

# %%
#Handle missing values, for example, by dropping rows with missing values
production_df = production_df.dropna()

# %%
# Explore the data by printing the first few rows and summary statistics
print(production_df.head())
print(production_df.describe())
# Out:
#                             Country Unnamed: 1     1990/91     1991/92  \
# 1                            Angola      (R/A)     50.3450     79.3310
# 2  Bolivia (Plurinational State of)        (A)    122.7770    103.5360
# 3                            Brazil      (A/R)  27285.6286  27293.4934
# 4                           Burundi      (A/R)    487.3930    667.1990
# 5                           Ecuador      (A/R)   1503.8150   2123.8240
#
#       1992/93     1993/94    1994/95     1995/96    1996/97    1997/98  ...  \
# 1     77.5200     32.6080     76.802     62.1090     70.925     64.330  ...
# 2    120.2350     50.8230    116.944    142.4850    124.579    140.719  ...
# 3  34603.3542  28166.9786  28192.047  18060.2022  29196.743  26148.004  ...
# 4    620.2380    393.3540    664.143    433.9800    400.969    249.785  ...
# 5   1185.4800   2069.0070   2375.766   1888.2330   1992.914   1190.663  ...
#
#       2010/11     2011/12     2012/13     2013/14     2014/15     2015/16  \
# ...

# %% [markdown]
# ## Handling Inventory Sheet with all the missing Values and Treating it right.

# %%
missing_inventory = inventory_df.isnull().sum()

# %%
inventory_df = inventory_df.dropna()

# %%
# Explore the data by printing the first few rows and summary statistics
print(inventory_df.head())
print(inventory_df.describe())
# Out:
#       Country   1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# 0     Austria  333.0  333.0  367.0  333.0  283.0  274.0  246.0  231.0  210.0
# 1      Cyprus   10.0   12.0   10.0    8.0   13.0   13.0   12.0    6.0    9.0
# 2     Denmark   89.0   89.0   89.0   89.0   89.0   89.0   89.0   89.0   89.0
# 3     Finland  176.0  223.0  213.0  188.0  282.0  220.0  140.0  181.0  162.0
# 4      France  573.0  562.0  537.0  389.0  481.0  301.0  266.0  317.0  350.0
#
#    ...  2010  2011  2012  2013  2014  2015  2016   2017       2018   2019
# 0  ...   141   111    97    92    96    96    90   80.0   80.00000   80.0
# 1  ...     5     6     4     7    12     6     2    3.3    5.46000    0.0
# 2  ...    89    89    89    89    89    89    89   89.0   89.00000   89.0
# 3  ...    83    83    83    83    83    83    83   83.0   83.00000   83.0
# 4  ...   427   414   446   438   499   507   572  474.7  463.56667  452.1
#
# [5 rows x 31 columns]
# ...

# %% [markdown]
# ### Handling Inventory Sheet with all the missing Values and Treating it right.

# %% [markdown]
# ### Visualization of trends in coffee inventoriest.show()

# %%
inventory_df
# Out:
#                      Country    1990    1991    1992    1993    1994    1995  \
# 0                    Austria   333.0   333.0   367.0   333.0   283.0   274.0
# 1                     Cyprus    10.0    12.0    10.0     8.0    13.0    13.0
# 2                    Denmark    89.0    89.0    89.0    89.0    89.0    89.0
# 3                    Finland   176.0   223.0   213.0   188.0   282.0   220.0
# 4                     France   573.0   562.0   537.0   389.0   481.0   301.0
# 5                    Germany  4000.0  1600.0  2500.0  2000.0  3900.0  2300.0
# 7                      Italy   215.0   189.0   187.0   228.0   222.0   217.0
# 8                Netherlands  1752.0  1752.0  1048.0   707.0   707.0   707.0
# 9                   Portugal    68.0   143.0   121.0   220.0   159.0    86.0
# 10                     Spain   200.0   250.0   333.0   250.0   267.0   284.0
# 11                    Sweden    87.0    87.0    87.0    87.0    87.0    87.0
# ...

# %%
# Explore the data by visualizing trends in coffee inventories over the years
plt.figure(figsize=(12, 6))
plt.plot(inventory_df['Country'], inventory_df['2019'], marker='o', linestyle='-')
plt.title('Coffee Inventory of Year 2019')
plt.xlabel('Countries')
plt.ylabel('Quantity of Inventory ( In thousand 60kg bags)')
source_text = "- Source: International Coffee Organization (2023)"
plt.text(0, -0.5, source_text, transform=plt.gca().transAxes, fontsize=10, ha='left', color='Blue')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
inventory_df.columns
# Out:
# Index(['Country',      1990,      1991,      1992,      1993,      1994,
#             1995,      1996,      1997,      1998,      1999,      2000,
#             2001,      2002,      2003,      2004,      2005,      2006,
#             2007,      2008,      2009,      2010,      2011,      2012,
#             2013,    '2014',    '2015',    '2016',    '2017',    '2018',
#           '2019'],
#       dtype='object')

# %% [markdown]
# # Consumption Dataset Trends and Evaluations

# %%
# Check for missing values
missing_values = consumption_df.isnull().sum()

# Summary statistics
summary_stats = consumption_df.describe()

# %%
consumption_df.columns
# Out:
# Index(['Country', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
# Plot a histogram of consumption values with different shades
plt.figure(figsize=(10, 9))
sns.histplot(data=consumption_df, bins=20, common_norm=False, color='blue', element='step', kde=True)
plt.title('Distribution of Coffee Consumption')
plt.xlabel('Consumption Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
consumption_df['Country']
# Out:
# 0                      Austria
# 1                      Belgium
# 2           Belgium/Luxembourg
# 3                     Bulgaria
# 4                      Croatia
# 5                       Cyprus
# 6                      Czechia
# 7                      Denmark
# 8                      Estonia
# 9                      Finland
# 10                      France
# 11                     Germany
# 12                      Greece
# 13                     Hungary
# 14                     Ireland
# 15                       Italy
# 16                      Latvia
# 17                   Lithuania
# 18                  Luxembourg
# 19                       Malta
# 20                 Netherlands
# 21                      Poland
# 22                    Portugal
# 23                     Romania
# 24                    Slovakia
# 25                    Slovenia
# 26                       Spain
# 27                      Sweden
# 28                       Japan
# 29                      Norway
# ...

# %%
# Check for missing values
missing_values = consumption_df.isnull().sum()

# %%
# Summary statistics
summary_stats = consumption_df.describe()

# %%
summary_stats
# Out:
#                1990          1991          1992          1993          1994  \
# count     26.000000     26.000000     32.000000     33.000000     33.000000
# mean    2281.624435   2458.859614   2027.547802   2081.929419   1931.582442
# std     3783.777509   4264.404247   3635.548769   3865.332528   3374.339474
# min       19.612998     12.945002      1.554000      8.800001      5.646998
# 25%      447.905252    346.619758    129.783503    147.587998    163.862001
# 50%      886.309001    833.097500    716.418490    690.230001    799.610000
# 75%     2374.086511   2451.180759   1866.673771   1794.731013   1742.163407
# max    18297.618001  18661.180001  18290.452996  19217.136997  17326.103994
#
#                1995          1996          1997          1998          1999  \
# count     33.000000     33.000000     33.000000     33.000000     34.000000
# mean    1987.669992   2023.641621   2015.906083   2058.404766   2002.962215
# ...

# %% [markdown]
# #### Coffee consumption trends in the US over years

# %%
# Define the countries to plot
countries = ['United States of America']
plt.figure(figsize=(12, 6))

for country in countries:
    if country in consumption_df['Country'].values:
        plt.plot(consumption_df.columns[1:], consumption_df[consumption_df['Country'] == country].values[0][1:], label=country)

plt.xlabel('Year')
plt.ylabel('Consumption (in thousands of 60kg bags')
plt.title('Coffee Consumption Trends in The United States (1990-2019)')
plt.xticks(rotation= 90)
plt.legend()
plt.show()

# %% [markdown]
# #### Top 5 Countries with the Highest Coffee Consumption in the Latest Year (2019):

# %%
# Sort data by 2019 consumption and get the top 5 countries
top_countries_2019 = consumption_df.sort_values(by='2019', ascending=False)
top_countries_2019.head()
# Out:
#                      Country          1990          1991          1992  \
# 34  United States of America  18297.618001  18661.180001  18290.452996
# 11                   Germany   7279.256961  12377.215949   9570.401951
# 28                     Japan   5059.848004   5808.974002   5132.431998
# 10                    France   5205.172363   5556.988033   5614.452697
# 15                     Italy   4832.293986   4254.039984   4132.135981
#
#             1993          1994          1995          1996          1997  \
# 34  19217.136997  17326.103994  17362.870986  18059.000790  17795.448195
# 11  11324.732941   8213.944942  11231.450951  10593.686345   9670.068157
# 28   5739.836005   5973.032006   6116.008005   5837.947004   5968.169000
# 10   5506.780037   5110.872038   5312.681708   5512.406007   5486.910846
# 15   4888.262978   4773.629974   4644.358975   4775.914473   4912.919079
#
#             1998  ...          2010          2011          2012          2013  \
# ...

# %% [markdown]
# ###  Trends in Coffee Consumption Over the Years in al countries

# %%
# Calculate the mean consumption for each year
mean_consumption = consumption_df.mean(numeric_only=True)

# Plot the average consumption trend over the years
plt.plot(mean_consumption.index, mean_consumption.values)
plt.xlabel('Year')
plt.ylabel('Average Consumption ( in thousands of 60kg bag')
plt.title('Average Coffee Consumption Trend Over the Years')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ### Calculate Yearly Consumption Growth:

# %%
# Calculate the yearly consumption growth rate
yearly_growth = mean_consumption.pct_change() * 100  # Calculate as a percentage

# Plot the yearly consumption growth
plt.bar(yearly_growth.index, yearly_growth.values)
plt.xlabel('Year')
plt.ylabel('Yearly Growth Rate (%)')
plt.title('Yearly Growth Rate of Coffee Consumption')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# ###  Identify Countries with the Highest Increase in Consumption:

# %%
# Calculate the percentage change in consumption from 1990 to 2019
consumption_df['Change_1990_to_2019'] = ((consumption_df['2019'] - consumption_df['1990']) / consumption_df['1990']) * 100

# Find the top 5 countries with the highest increase in consumption
top_growth_countries = consumption_df.sort_values(by='Change_1990_to_2019', ascending=False)
top_growth_countries.head()
# Out:
#         Country        1990        1991         1992         1993  \
# 21       Poland  334.592001  243.024002  1650.229026  1544.714877
# 32      Tunisia  100.999998   90.201001   110.583001   100.624001
# 3      Bulgaria  101.782998   16.761001   174.878012   326.955006
# 5        Cyprus   30.570999   44.697000    39.303999    77.516000
# 14      Ireland  119.885001  112.966001    90.729000   107.310001
#
#            1994         1995         1996         1997         1998  ...  \
# 21  1742.163407  1636.660097  1755.456208  1966.017606  1964.537617  ...
# 32   137.267000   136.783001   143.650001   164.617001   147.417000  ...
# 3    352.764006   393.408007   246.474995   274.918003   324.160004  ...
# 5     45.369001    42.678000    51.740999    46.495999    46.205999  ...
# 14   127.123001   106.530001    86.773002    96.958601    91.735901  ...
#
#            2011         2012         2013         2014         2015  \
# ...

# %%
top_growth_countries[['Country', 'Change_1990_to_2019']].head()
# Out:
#         Country  Change_1990_to_2019
# 21       Poland           647.366599
# 32      Tunisia           403.151743
# 3      Bulgaria           315.655520
# 5        Cyprus           277.562320
# 14      Ireland           208.244181

# %%
# Plot the distribution of coffee consumption in 2019
plt.figure(figsize=(10, 6))
sns.histplot(data=consumption_df, x='2019', bins=20, kde=True)
plt.xlabel('Consumption in 2019 ( In thousand 60kg bags)')
plt.ylabel('Count ')
plt.title('Distribution of Coffee Consumption in 2019 (in thousands of 60')
plt.show()

# %% [markdown]
# ### Overall Consumption Trends (1990-2019)

# %%
import matplotlib.pyplot as plt

# Calculate the total consumption for each year
total_consumption = consumption_df.iloc[:, 1:].sum()

# Plot the overall consumption trends
plt.figure(figsize=(12, 6))
plt.plot(total_consumption.index, total_consumption.values, marker='o', linestyle='-')
plt.title('Overall Coffee Consumption Trends (1990-2019)')
plt.xlabel('Year')
plt.xticks(rotation = 90)
plt.ylabel('Total Consumption (in thousands of 60kg bags)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Top 5 countries in 2019

# %%
# Filter the data for the year 2019
consumption_2019 = consumption_df[['Country', '2019']]

# Sort by consumption in 2019 and get the top 5 consumers
top_consumers_2019 = consumption_2019.sort_values(by='2019', ascending=False).head(5)

# Display the top 5 consumers in 2019
print("Top 5 Coffee Consumers in 2019:")
print(top_consumers_2019)
# Out:
# Top 5 Coffee Consumers in 2019:
#                      Country          2019
# 34  United States of America  27309.950887
# 11                   Germany   8670.044801
# 28                     Japan   7550.821826
# 10                    France   6192.440140
# 15                     Italy   5469.078443

# %% [markdown]
# ### Bottom 5 consumber in 2019

# %%
# Sort by consumption in 2019 and get the bottom 5 consumers
bottom_consumers_2019 = consumption_2019.sort_values(by='2019').head(5)

# Display the bottom 5 consumers in 2019
print("Bottom 5 Coffee Consumers in 2019:")
print(bottom_consumers_2019)
# Out:
# Bottom 5 Coffee Consumers in 2019:
#         Country        2019
# 19        Malta   23.115946
# 16       Latvia  113.693194
# 5        Cyprus  115.424574
# 8       Estonia  122.509844
# 25     Slovenia  204.011212

# %% [markdown]
# #### Distribution of consumption in 2019

# %%
# Plot a histogram to visualize the distribution of consumption in 2019
plt.figure(figsize=(10, 6))
plt.hist(consumption_2019['2019'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Coffee Consumption in 2019')
plt.xlabel('Consumption (in thousands of 60kg bags)')
plt.ylabel('Number of Countries')
plt.grid(True)
plt.show()

# %%
# Calculate the total consumption for each year
total_import = import_df.iloc[:, 1:].sum()

# Plot the overall consumption trends
plt.figure(figsize=(12, 6))
plt.plot(total_import.index, total_import.values, marker='o', linestyle='-')
plt.title('Overall Coffee Import Trends (1990-2019)')
plt.xlabel('Year')
plt.xticks(rotation = 90)
plt.ylabel('Total Import (in thousands of 60kg bags)')
plt.grid(True)
plt.show()
